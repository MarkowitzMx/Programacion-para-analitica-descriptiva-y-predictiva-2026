# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkowitzMx/Programacion-para-analitica-descriptiva-y-predictiva-2026/blob/main/Copy_of_Actividad_Ejercicio2_OpenMeteo_Sesion8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividad — Comparar el clima entre varias ciudades con Open-Meteo (Sesión 8)
#
# En el Bloque 2 consultaste el pronóstico por hora de Ciudad Juárez con Open-Meteo. En esta actividad usas
# la misma API, pero de otra forma: en vez de un pronóstico por hora de una sola ciudad, se consulta el
# **clima actual** de **varias ciudades distintas** y se construye una tabla comparativa.
#
# **Endpoint:** `https://api.open-meteo.com/v1/forecast`
# **Parámetro clave:** `current_weather=true` — regresa un solo valor actual (no una lista por hora) dentro
# de `datos["current_weather"]`, con `temperature`, `windspeed`, `weathercode` y `time`.
#
# **Instrucciones:**
#
# 1. Define una lista `ciudades` con al menos tres ciudades (nombre, latitud, longitud), distintas a
#    Ciudad Juárez.
# 2. Para cada ciudad, consulta el endpoint con `current_weather=true`, usando `timeout` y manejo de
#    errores como en el Bloque 2.
# 3. De cada respuesta, extrae la temperatura y la velocidad del viento actuales.
# 4. Estructura la información como una lista de diccionarios llamada `info_clima`.
# 5. Convierte `info_clima` en un DataFrame llamado `df_clima_ciudades`.
# 6. Verifica el resultado.

# %% [markdown]
# **Paso 1 — Define las ciudades a consultar.**

# %%
ciudades = [
    {"nombre": "Chihuahua", "latitud": 28.63, "longitud": -106.09},
    {"nombre": "Monterrey", "latitud": 25.69, "longitud": -100.32},
    {"nombre": "Guadalajara", "latitud": 20.66, "longitud": -103.35},
    {"nombre": "Ciudad de México", "latitud": 19.43, "longitud": -99.13},
    {"nombre": "Tijuana", "latitud": 32.53, "longitud": -117.02},
    {"nombre": "Mérida", "latitud": 20.97, "longitud": -89.62},
    {"nombre": "Cancún", "latitud": 21.16, "longitud": -86.85},
    {"nombre": "Puebla", "latitud": 19.04, "longitud": -98.20},
    {"nombre": "Hermosillo", "latitud": 29.10, "longitud": -110.98},
    {"nombre": "Tampico", "latitud": 22.24, "longitud": -97.86},
    {"nombre": "Oaxaca", "latitud": 17.06, "longitud": -96.73},
    {"nombre": "La Paz", "latitud": 24.14, "longitud": -110.31},
]  # puedes cambiar o agregar ciudades

# %% [markdown]
# **Pasos 2 a 4 — Consultar cada ciudad y estructurar la información.**

# %%
import requests

info_clima = []

for ciudad in ciudades:
    endpoint = "https://api.open-meteo.com/v1/forecast"
    parametros = {
        "latitude": ciudad["latitud"],
        "longitude": ciudad["longitud"],
        "current_weather": True,
    }

    # Completa: envía la solicitud con timeout, revisa status_code con raise_for_status()
    try:
        respuesta = requests.get(endpoint, params=parametros, timeout=10)
        respuesta.raise_for_status()

        datos = respuesta.json()
        clima_actual = datos["current_weather"]

        # Completa: extrae temperature y windspeed de clima_actual
        info_clima.append({
            "ciudad": ciudad["nombre"],
            "temperatura": clima_actual["temperature"],
            "viento": clima_actual["windspeed"],
        })

    except requests.RequestException as error:
        print(f"No fue posible consultar {ciudad['nombre']}:", error)

info_clima
# Out:
# [{'ciudad': 'Chihuahua', 'temperatura': 25.8, 'viento': 7.9},
#  {'ciudad': 'Monterrey', 'temperatura': 28.3, 'viento': 12.8},
#  {'ciudad': 'Guadalajara', 'temperatura': 20.9, 'viento': 2.6},
#  {'ciudad': 'Ciudad de México', 'temperatura': 14.0, 'viento': 1.7},
#  {'ciudad': 'Tijuana', 'temperatura': 22.9, 'viento': 5.4},
#  {'ciudad': 'Mérida', 'temperatura': 25.9, 'viento': 4.6},
#  {'ciudad': 'Cancún', 'temperatura': 27.3, 'viento': 6.6},
#  {'ciudad': 'Puebla', 'temperatura': 16.2, 'viento': 1.0},
#  {'ciudad': 'Hermosillo', 'temperatura': 32.0, 'viento': 7.8},
#  {'ciudad': 'Tampico', 'temperatura': 27.5, 'viento': 5.4},
#  {'ciudad': 'Oaxaca', 'temperatura': 17.0, 'viento': 8.8},
#  {'ciudad': 'La Paz', 'temperatura': 29.5, 'viento': 10.0}]

# %% [markdown]
# **Paso 5 — Construir el DataFrame.**

# %%
# Completa: convierte info_clima en un DataFrame llamado df_clima_ciudades
import pandas as pd
df_clima_ciudades = pd.DataFrame(info_clima)
df_clima_ciudades
# Out:
#               ciudad  temperatura  viento
# 0          Chihuahua         25.8     7.9
# 1          Monterrey         28.3    12.8
# 2        Guadalajara         20.9     2.6
# 3   Ciudad de México         14.0     1.7
# 4            Tijuana         22.9     5.4
# 5             Mérida         25.9     4.6
# 6             Cancún         27.3     6.6
# 7             Puebla         16.2     1.0
# 8         Hermosillo         32.0     7.8
# 9            Tampico         27.5     5.4
# 10            Oaxaca         17.0     8.8
# 11            La Paz         29.5    10.0

# %% [markdown]
# **Paso 6 — Verificar el resultado.**

# %%
# Completa: imprime shape, columns y valores faltantes de df_clima_ciudades
print("Shape:", df_clima_ciudades.shape)
print("Columnas:", df_clima_ciudades.columns.tolist())
print("Valores faltantes por columna:")
print(df_clima_ciudades.isnull().sum())
# Out:
# Shape: (12, 3)
# Columnas: ['ciudad', 'temperatura', 'viento']
# Valores faltantes por columna:
# ciudad         0
# temperatura    0
# viento         0
# dtype: int64
